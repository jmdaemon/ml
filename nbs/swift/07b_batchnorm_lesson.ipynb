// %%
%install '.package(path: "$cwd/FastaiNotebook_06_cuda")' FastaiNotebook_06_cuda
// Out:
// Installing packages:
// 	.package(path: "/home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda")
// 		FastaiNotebook_06_cuda
// With SwiftPM flags: []
// Working in: /tmp/tmpgogsn7vy/swift-install
// /home/jmd/swift/usr/bin/swift-build: /home/jmd/anaconda3/lib/libcurl.so.4: no version information available (required by /home/jmd/swift/usr/lib/swift/linux/libFoundationNetworking.so)
// Fetching https://github.com/saeta/Just
// Fetching https://github.com/latenitesoft/NotebookExport
// Fetching https://github.com/mxcl/Path.swift
// Cloning https://github.com/mxcl/Path.swift
// Resolving https://github.com/mxcl/Path.swift at 0.16.3
// Cloning https://github.com/saeta/Just
// Resolving https://github.com/saeta/Just at 0.7.3
// Cloning https://github.com/latenitesoft/NotebookExport
// Resolving https://github.com/latenitesoft/NotebookExport at 0.6.0
// [1/25] Compiling Path Path+StringConvertibles.swift
// [2/25] Compiling Path Path+ls.swift
// [3/25] Compiling Just Just.swift
// [4/25] Compiling Path Path+Attributes.swift
// [5/25] Compiling Path Path+Codable.swift
// [6/25] Compiling Path Path+CommonDirectories.swift
// [7/25] Compiling Path Path+FileManager.swift
// [8/25] Compiling Path Path->Bool.swift
// [9/25] Compiling Path Path.swift
// [10/26] Merging module Path
// [11/30] Wrapping AST for Path for debugging
// [12/30] Compiling NotebookExport DependencyDescription.swift
// [13/30] Compiling NotebookExport ExtensionUtils.swift
// [14/30] Compiling NotebookExport PackageManifest.swift
// [16/31] Merging module Just
// [17/31] Wrapping AST for Just for debugging
// [18/31] Compiling NotebookExport NotebookExport.swift
// [19/32] Merging module NotebookExport
// [20/33] Wrapping AST for NotebookExport for debugging
// [21/33] Compiling FastaiNotebook_00_load_data 00_load_data.swift
// [22/34] Merging module FastaiNotebook_00_load_data
// [23/36] Wrapping AST for FastaiNotebook_00_load_data for debugging
// [24/36] Compiling FastaiNotebook_01_matmul 01_matmul.swift
// [25/36] Compiling FastaiNotebook_01_matmul 00_load_data.swift
// [26/37] Merging module FastaiNotebook_01_matmul
// [27/39] Wrapping AST for FastaiNotebook_01_matmul for debugging
// [28/40] Compiling FastaiNotebook_01a_fastai_layers 01_matmul.swift
// [29/40] Compiling FastaiNotebook_01a_fastai_layers 00_load_data.swift
// [30/40] Compiling FastaiNotebook_01a_fastai_layers 01a_fastai_layers.swift
// [31/41] Merging module FastaiNotebook_01a_fastai_layers
// [32/43] Wrapping AST for FastaiNotebook_01a_fastai_layers for debugging
// [33/45] Compiling FastaiNotebook_02_fully_connected 01_matmul.swift
// [34/45] Compiling FastaiNotebook_02_fully_connected 02_fully_connected.swift
// [35/45] Compiling FastaiNotebook_02_fully_connected 00_load_data.swift
// [36/45] Compiling FastaiNotebook_02_fully_connected 01a_fastai_layers.swift
// [37/46] Merging module FastaiNotebook_02_fully_connected
// [38/48] Wrapping AST for FastaiNotebook_02_fully_connected for debugging
// [39/51] Compiling FastaiNotebook_02a_why_sqrt5 02_fully_connected.swift
// [40/51] Compiling FastaiNotebook_02a_why_sqrt5 02a_why_sqrt5.swift
// [41/51] Compiling FastaiNotebook_02a_why_sqrt5 00_load_data.swift
// [42/51] Compiling FastaiNotebook_02a_why_sqrt5 01_matmul.swift
// [43/51] Compiling FastaiNotebook_02a_why_sqrt5 01a_fastai_layers.swift
// [44/52] Merging module FastaiNotebook_02a_why_sqrt5
// [45/53] Wrapping AST for FastaiNotebook_02a_why_sqrt5 for debugging
// [46/58] Compiling FastaiNotebook_03_minibatch_training 03_minibatch_training.swift
// [47/58] Compiling FastaiNotebook_03_minibatch_training 02a_why_sqrt5.swift
// [48/58] Compiling FastaiNotebook_03_minibatch_training 00_load_data.swift
// [49/58] Compiling FastaiNotebook_03_minibatch_training 01_matmul.swift
// [50/58] Compiling FastaiNotebook_03_minibatch_training 01a_fastai_layers.swift
// [51/58] Compiling FastaiNotebook_03_minibatch_training 02_fully_connected.swift
// [52/59] Merging module FastaiNotebook_03_minibatch_training
// [53/61] Wrapping AST for FastaiNotebook_03_minibatch_training for debugging
// [54/66] Compiling FastaiNotebook_04_callbacks 02a_why_sqrt5.swift
// [55/66] Compiling FastaiNotebook_04_callbacks 03_minibatch_training.swift
// [56/66] Compiling FastaiNotebook_04_callbacks 00_load_data.swift
// [57/66] Compiling FastaiNotebook_04_callbacks 01_matmul.swift
// [58/66] Compiling FastaiNotebook_04_callbacks 04_callbacks.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:35:20: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var ds: Dataset<Element> {
//                    ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:41:23: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(_ ds: Dataset<Element>, len: Int, shuffle: Bool = false, bs: Int = 64) {
//                       ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:49:24: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:49:49: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                                                 ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:36:38: warning: 'batched' is deprecated
//         if !shuffle { return innerDs.batched(bs)}
//                                      ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:38:24: warning: 'shuffled(sampleCount:randomSeed:reshuffleForEachIterator:)' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:38:73: warning: 'batched' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                                                                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:58:29: warning: 'init(elements:)' is deprecated
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_04_callbacks/Sources/FastaiNotebook_04_callbacks/04_callbacks.swift:59:29: warning: 'init(elements:)' is deprecated
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// [59/66] Compiling FastaiNotebook_04_callbacks 01a_fastai_layers.swift
// [60/66] Compiling FastaiNotebook_04_callbacks 02_fully_connected.swift
// [61/67] Merging module FastaiNotebook_04_callbacks
// [62/69] Wrapping AST for FastaiNotebook_04_callbacks for debugging
// [63/75] Compiling FastaiNotebook_05_anneal 02a_why_sqrt5.swift
// [64/75] Compiling FastaiNotebook_05_anneal 03_minibatch_training.swift
// [65/75] Compiling FastaiNotebook_05_anneal 00_load_data.swift
// [66/75] Compiling FastaiNotebook_05_anneal 01_matmul.swift
// [67/75] Compiling FastaiNotebook_05_anneal 04_callbacks.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:35:20: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var ds: Dataset<Element> {
//                    ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:41:23: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(_ ds: Dataset<Element>, len: Int, shuffle: Bool = false, bs: Int = 64) {
//                       ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:49:24: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:49:49: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                                                 ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:36:38: warning: 'batched' is deprecated
//         if !shuffle { return innerDs.batched(bs)}
//                                      ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:38:24: warning: 'shuffled(sampleCount:randomSeed:reshuffleForEachIterator:)' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:38:73: warning: 'batched' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                                                                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:58:29: warning: 'init(elements:)' is deprecated
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:59:29: warning: 'init(elements:)' is deprecated
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// [68/75] Compiling FastaiNotebook_05_anneal 05_anneal.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:35:20: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var ds: Dataset<Element> {
//                    ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:41:23: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(_ ds: Dataset<Element>, len: Int, shuffle: Bool = false, bs: Int = 64) {
//                       ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:49:24: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:49:49: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                                                 ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:36:38: warning: 'batched' is deprecated
//         if !shuffle { return innerDs.batched(bs)}
//                                      ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:38:24: warning: 'shuffled(sampleCount:randomSeed:reshuffleForEachIterator:)' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:38:73: warning: 'batched' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                                                                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:58:29: warning: 'init(elements:)' is deprecated
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05_anneal/Sources/FastaiNotebook_05_anneal/04_callbacks.swift:59:29: warning: 'init(elements:)' is deprecated
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// [69/75] Compiling FastaiNotebook_05_anneal 01a_fastai_layers.swift
// [70/75] Compiling FastaiNotebook_05_anneal 02_fully_connected.swift
// [71/76] Merging module FastaiNotebook_05_anneal
// [72/78] Wrapping AST for FastaiNotebook_05_anneal for debugging
// [73/85] Compiling FastaiNotebook_05b_early_stopping 02_fully_connected.swift
// [74/85] Compiling FastaiNotebook_05b_early_stopping 02a_why_sqrt5.swift
// [75/85] Compiling FastaiNotebook_05b_early_stopping 05_anneal.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// [76/85] Compiling FastaiNotebook_05b_early_stopping 05b_early_stopping.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// [77/85] Compiling FastaiNotebook_05b_early_stopping 03_minibatch_training.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:35:20: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var ds: Dataset<Element> {
//                    ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:41:23: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(_ ds: Dataset<Element>, len: Int, shuffle: Bool = false, bs: Int = 64) {
//                       ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:49:24: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:49:49: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                                                 ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:36:38: warning: 'batched' is deprecated
//         if !shuffle { return innerDs.batched(bs)}
//                                      ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:38:24: warning: 'shuffled(sampleCount:randomSeed:reshuffleForEachIterator:)' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:38:73: warning: 'batched' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                                                                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:58:29: warning: 'init(elements:)' is deprecated
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:59:29: warning: 'init(elements:)' is deprecated
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// [78/85] Compiling FastaiNotebook_05b_early_stopping 04_callbacks.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:35:20: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var ds: Dataset<Element> {
//                    ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:41:23: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(_ ds: Dataset<Element>, len: Int, shuffle: Bool = false, bs: Int = 64) {
//                       ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:49:24: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:49:49: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                                                 ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:36:38: warning: 'batched' is deprecated
//         if !shuffle { return innerDs.batched(bs)}
//                                      ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:38:24: warning: 'shuffled(sampleCount:randomSeed:reshuffleForEachIterator:)' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:38:73: warning: 'batched' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                                                                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:58:29: warning: 'init(elements:)' is deprecated
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_05b_early_stopping/Sources/FastaiNotebook_05b_early_stopping/04_callbacks.swift:59:29: warning: 'init(elements:)' is deprecated
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// [79/85] Compiling FastaiNotebook_05b_early_stopping 00_load_data.swift
// [80/85] Compiling FastaiNotebook_05b_early_stopping 01_matmul.swift
// [81/85] Compiling FastaiNotebook_05b_early_stopping 01a_fastai_layers.swift
// [82/86] Merging module FastaiNotebook_05b_early_stopping
// [83/88] Wrapping AST for FastaiNotebook_05b_early_stopping for debugging
// [84/96] Compiling FastaiNotebook_06_cuda 05b_early_stopping.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// [85/96] Compiling FastaiNotebook_06_cuda 06_cuda.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// [86/96] Compiling FastaiNotebook_06_cuda 02_fully_connected.swift
// [87/96] Compiling FastaiNotebook_06_cuda 02a_why_sqrt5.swift
// [88/96] Compiling FastaiNotebook_06_cuda 03_minibatch_training.swift
// [89/96] Compiling FastaiNotebook_06_cuda 04_callbacks.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:35:20: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var ds: Dataset<Element> {
//                    ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:41:23: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(_ ds: Dataset<Element>, len: Int, shuffle: Bool = false, bs: Int = 64) {
//                       ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:49:24: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:49:49: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                                                 ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:36:38: warning: 'batched' is deprecated
//         if !shuffle { return innerDs.batched(bs)}
//                                      ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:38:24: warning: 'shuffled(sampleCount:randomSeed:reshuffleForEachIterator:)' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:38:73: warning: 'batched' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                                                                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:58:29: warning: 'init(elements:)' is deprecated
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:59:29: warning: 'init(elements:)' is deprecated
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// [90/96] Compiling FastaiNotebook_06_cuda 05_anneal.swift
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:27:25: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var innerDs: Dataset<Element>
//                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:35:20: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public var ds: Dataset<Element> {
//                    ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:41:23: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(_ ds: Dataset<Element>, len: Int, shuffle: Bool = false, bs: Int = 64) {
//                       ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:49:24: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:49:49: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     public init(train: Dataset<Element>, valid: Dataset<Element>, trainLen: Int, validLen: Int, bs: Int = 64) {
//                                                 ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:36:38: warning: 'batched' is deprecated
//         if !shuffle { return innerDs.batched(bs)}
//                                      ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:38:24: warning: 'shuffled(sampleCount:randomSeed:reshuffleForEachIterator:)' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                        ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:38:73: warning: 'batched' is deprecated
//         return innerDs.shuffled(sampleCount: dsCount, randomSeed: seed).batched(bs)
//                                                                         ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:58:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:59:29: warning: 'Dataset' is deprecated: Datasets will be removed in S4TF v0.10. Please use the new Batches API instead.
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:58:29: warning: 'init(elements:)' is deprecated
//     return DataBunch(train: Dataset(elements: DataBatch(xb:xTrain, yb: yTrain)),
//                             ^
// /home/jmd/workspace/ml/fastai/nbs/swift/FastaiNotebook_06_cuda/Sources/FastaiNotebook_06_cuda/04_callbacks.swift:59:29: warning: 'init(elements:)' is deprecated
//                      valid: Dataset(elements: DataBatch(xb:xValid, yb: yValid)),
//                             ^
// [91/96] Compiling FastaiNotebook_06_cuda 00_load_data.swift
// [92/96] Compiling FastaiNotebook_06_cuda 01_matmul.swift
// [93/96] Compiling FastaiNotebook_06_cuda 01a_fastai_layers.swift
// [94/97] Merging module FastaiNotebook_06_cuda
// [95/98] Wrapping AST for FastaiNotebook_06_cuda for debugging
// [96/98] Compiling jupyterInstalledPackages jupyterInstalledPackages.swift
// [97/99] Merging module jupyterInstalledPackages
// [98/99] Wrapping AST for jupyterInstalledPackages for debugging
// [99/99] Linking libjupyterInstalledPackages.so
// Initializing Swift...
// Installation complete!

// %%
import FastaiNotebook_06_cuda
%include "EnableIPythonDisplay.swift"
IPythonDisplay.shell.enable_matplotlib("inline")
// Out:
// ('inline', 'module://ipykernel.pylab.backend_inline')

// %%
//export
import Path
import TensorFlow
#if canImport(PythonKit)
    import PythonKit
#else
    import Python
#endif

// %%
class AlmostBatchNorm<Scalar: TensorFlowFloatingPoint> { // : Layer
    // Configuration hyperparameters
    let momentum, epsilon: Scalar
    // Running statistics
    var runningMean, runningVariance: Tensor<Scalar>
    // Trainable parameters
    var scale, offset: Tensor<Scalar>
    
    init(featureCount: Int, momentum: Scalar = 0.9, epsilon: Scalar = 1e-5) {
        (self.momentum, self.epsilon) = (momentum, epsilon)
        (scale, offset) = (Tensor(ones: [featureCount]), Tensor(zeros: [featureCount]))
        (runningMean, runningVariance) = (Tensor(0), Tensor(1))
    }

    func call(_ input: Tensor<Scalar>) -> Tensor<Scalar> {
        let mean, variance: Tensor<Scalar>
        switch Context.local.learningPhase {
        case .training:
            mean = input.mean(alongAxes: [0, 1, 2])
            variance = input.variance(alongAxes: [0, 1, 2])
            runningMean += (mean - runningMean) * (1 - momentum)
            runningVariance += (variance - runningVariance) * (1 - momentum)
        case .inference:
            (mean, variance) = (runningMean, runningVariance)
        }
        let normalizer = rsqrt(variance + epsilon) * scale
        return (input - mean) * normalizer + offset
    }
}

// %%
//export
public class Reference<T> {
    public var value: T
    public init(_ value: T) { self.value = value }
}

// %%
//export
public protocol LearningPhaseDependent: FALayer {
    associatedtype Input
    associatedtype Output
    @differentiable func forwardTraining (_ input: Input) -> Output
    @differentiable func forwardInference(_ input: Input) -> Output
}

extension LearningPhaseDependent {
    @differentiable 
    public func forward(_ input: Input) -> Output {
        switch Context.local.learningPhase {
        case .training:  return forwardTraining(input)
        case .inference: return forwardInference(input)
        }
    }
    
    func gradForward(_ input: Input) ->
        (value: Output, pullback: (Self.Output.TangentVector) ->
            (Self.TangentVector, Self.Input.TangentVector)) {
        switch Context.local.learningPhase {
        case .training:  return valueWithPullback(at: input) { $0.forwardTraining($1)  }
        case .inference: return valueWithPullback(at: input) { $0.forwardInference($1) }
        }
    }
}
// Out:
// error: <Cell 30>:18:2: error: can only differentiate functions with results that conform to 'Differentiable', but '(value: Self.Output, pullback: (Self.Output.TangentVector) -> (Self.TangentVector, Self.Input.TangentVector))' does not conform to 'Differentiable'
// @differentiable
//  ^
//
// error: <Cell 30>:23:33: error: type of expression is ambiguous without more context
//         case .training:  return valueWithPullback(at: input) { $0.forwardTraining($1)  }
//                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
//
// error: <Cell 30>:24:33: error: type of expression is ambiguous without more context
//         case .inference: return valueWithPullback(at: input) { $0.forwardInference($1) }
//                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

// %%
//export
public protocol Norm: FALayer where Input == TF, Output == TF {
    init(_ featureCount: Int, epsilon: Float)
}

public struct FABatchNorm: LearningPhaseDependent, Norm {
    // Configuration hyperparameters
    @noDerivative var momentum, epsilon: Float
    // Running statistics
    @noDerivative let runningMean, runningVariance: Reference<TF>
    // Trainable parameters
    public var scale, offset: TF
    
    public init(_ featureCount: Int, momentum: Float, epsilon: Float = 1e-5) {
        self.momentum = momentum
        self.epsilon = epsilon
        self.scale = Tensor(ones: [featureCount])
        self.offset = Tensor(zeros: [featureCount])
        self.runningMean = Reference(Tensor(0))
        self.runningVariance = Reference(Tensor(1))
    }
    
    public init(_ featureCount: Int, epsilon: Float = 1e-5) {
        self.init(featureCount, momentum: 0.9, epsilon: epsilon)
    }

    @differentiable
    public func forwardTraining(_ input: TF) -> TF {
        let mean = input.mean(alongAxes: [0, 1, 2])
        let variance = input.variance(alongAxes: [0, 1, 2])
        runningMean.value += (mean - runningMean.value) * (1 - momentum)
        runningVariance.value += (variance - runningVariance.value) * (1 - momentum)
        let normalizer = rsqrt(variance + epsilon) * scale
        return (input - mean) * normalizer + offset
    }
    
    @differentiable
    public func forwardInference(_ input: TF) -> TF {
        let (mean, variance) = (runningMean.value, runningVariance.value)
        let normalizer = rsqrt(variance + epsilon) * scale
        return (input - mean) * normalizer + offset
    }
}
// Out:
// error: <Cell 21>:6:28: error: cannot find type 'LearningPhaseDependent' in scope
// public struct FABatchNorm: LearningPhaseDependent, Norm {
//                            ^~~~~~~~~~~~~~~~~~~~~~
//
// error: <Cell 21>:6:15: error: type 'FABatchNorm' does not conform to protocol 'FALayer'
// public struct FABatchNorm: LearningPhaseDependent, Norm {
//               ^
