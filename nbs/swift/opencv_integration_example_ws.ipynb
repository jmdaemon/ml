// %%
# Uncomment line below when using Colab (this installs OpenCV4)
# %system SwiftCV/install/install_colab.sh
%install-location $cwd/swift-install
%install '.package(path: "$cwd/SwiftCV")' SwiftCV
%install '.package(path: "$cwd/FastaiNotebook_08_data_block")' FastaiNotebook_08_data_block
// Out:
// Installing packages:
// 	.package(path: "/home/jmd/workspace/fastai/course-v3/nbs/swift/SwiftCV")
// 		SwiftCV
// 	.package(path: "/home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_08_data_block")
// 		FastaiNotebook_08_data_block
// With SwiftPM flags: []
// Working in: /tmp/tmpg5xusel_/swift-install
// /home/jmd/swift/usr/bin/swift-build: /home/jmd/anaconda3/lib/libcurl.so.4: no version information available (required by /home/jmd/swift/usr/lib/swift/linux/libFoundationNetworking.so)
// [1/32] Compiling COpenCV version.cpp
// [2/32] Compiling COpenCV imgcodecs.cpp
// [3/32] Compiling COpenCV core.cpp
// [4/32] Compiling COpenCV imgproc.cpp
// [5/36] Compiling SwiftCV Enums.swift
// [6/36] Compiling Path Path+StringConvertibles.swift
// [7/36] Compiling Path Path+ls.swift
// [8/36] Compiling SwiftCV TensorFlowConversion.swift
// [9/36] Compiling Path Path+FileManager.swift
// [10/36] Compiling SwiftCV ConcurrentMap.swift
// [11/36] Compiling Path Path->Bool.swift
// [12/36] Compiling Path Path.swift
// [15/36] Compiling SwiftCV SwiftCV.swift
// [18/38] Merging module Path
// [19/38] Wrapping AST for Path for debugging
// [20/42] Merging module SwiftCV
// [21/42] Wrapping AST for SwiftCV for debugging
// [22/42] Compiling NotebookExport DependencyDescription.swift
// [23/42] Compiling NotebookExport PackageManifest.swift
// [24/42] Compiling NotebookExport ExtensionUtils.swift
// [26/43] Merging module Just
// [27/43] Wrapping AST for Just for debugging
// [28/43] Compiling NotebookExport NotebookExport.swift
// [29/44] Merging module NotebookExport
// [30/44] Wrapping AST for NotebookExport for debugging
// [31/45] Compiling FastaiNotebook_00_load_data 00_load_data.swift
// [32/46] Merging module FastaiNotebook_00_load_data
// [33/46] Wrapping AST for FastaiNotebook_00_load_data for debugging
// [34/48] Compiling FastaiNotebook_01_matmul 01_matmul.swift
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01_matmul/Sources/FastaiNotebook_01_matmul/01_matmul.swift:18:16: warning: 'Raw' is deprecated: 'Raw' has been renamed to '_Raw' to indicate that it is not a guaranteed/stable API.
//         self = Raw.readFile(filename: filename)
//                ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01_matmul/Sources/FastaiNotebook_01_matmul/01_matmul.swift:18:16: note: use '_Raw' instead
//         self = Raw.readFile(filename: filename)
//                ^~~
//                _Raw
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01_matmul/Sources/FastaiNotebook_01_matmul/01_matmul.swift:23:16: warning: 'Raw' is deprecated: 'Raw' has been renamed to '_Raw' to indicate that it is not a guaranteed/stable API.
//         return Raw.decodeJpeg(contents: self, channels: Int64(channels), dctMethod: "")
//                ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01_matmul/Sources/FastaiNotebook_01_matmul/01_matmul.swift:23:16: note: use '_Raw' instead
//         return Raw.decodeJpeg(contents: self, channels: Int64(channels), dctMethod: "")
//                ^~~
//                _Raw
// [35/48] Compiling FastaiNotebook_01_matmul 00_load_data.swift
// [36/49] Merging module FastaiNotebook_01_matmul
// [37/50] Wrapping AST for FastaiNotebook_01_matmul for debugging
// [38/52] Compiling FastaiNotebook_01a_fastai_layers 01_matmul.swift
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01_matmul.swift:18:16: warning: 'Raw' is deprecated: 'Raw' has been renamed to '_Raw' to indicate that it is not a guaranteed/stable API.
//         self = Raw.readFile(filename: filename)
//                ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01_matmul.swift:18:16: note: use '_Raw' instead
//         self = Raw.readFile(filename: filename)
//                ^~~
//                _Raw
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01_matmul.swift:23:16: warning: 'Raw' is deprecated: 'Raw' has been renamed to '_Raw' to indicate that it is not a guaranteed/stable API.
//         return Raw.decodeJpeg(contents: self, channels: Int64(channels), dctMethod: "")
//                ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01_matmul.swift:23:16: note: use '_Raw' instead
//         return Raw.decodeJpeg(contents: self, channels: Int64(channels), dctMethod: "")
//                ^~~
//                _Raw
// [39/52] Compiling FastaiNotebook_01a_fastai_layers 00_load_data.swift
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:300:21: error: expected 'wrt:' or 'where' in '@differentiable' attribute
//     @differentiable(vjp: _vjpApplied)
//                     ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:48:21: error: expected 'wrt:' or 'where' in '@differentiable' attribute
//     @differentiable(vjp: callGrad)
//                     ^
// [40/52] Compiling FastaiNotebook_01a_fastai_layers 01a_fastai_layers.swift
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:48:21: error: expected 'wrt:' or 'where' in '@differentiable' attribute
//     @differentiable(vjp: callGrad)
//                     ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:300:21: error: expected 'wrt:' or 'where' in '@differentiable' attribute
//     @differentiable(vjp: _vjpApplied)
//                     ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:77:15: error: type 'FADense<Scalar>' does not conform to protocol 'Layer'
// public struct FADense<Scalar: TensorFlowFloatingPoint>: FALayer {
//               ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:49:10: note: candidate is missing attribute '@differentiable'
//     func callAsFunction(_ input: Input) -> Output {
//          ^
//     @differentiable
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:77:15: error: type 'FADense<Scalar>' does not conform to protocol 'Module'
// public struct FADense<Scalar: TensorFlowFloatingPoint>: FALayer {
//               ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:49:10: note: candidate is missing attribute '@differentiable'
//     func callAsFunction(_ input: Input) -> Output {
//          ^
//     @differentiable
// TensorFlow.Layer:3:10: note: protocol requires function 'callAsFunction' with type '(FADense<Scalar>.Input) -> FADense<Scalar>.Output'
//     func callAsFunction(_ input: Self.Input) -> Self.Output
//          ^
// TensorFlow.Module:5:10: note: protocol requires function 'callAsFunction' with type '(FADense<Scalar>.Input) -> FADense<Scalar>.Output'
//     func callAsFunction(_ input: Self.Input) -> Self.Output
//          ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:113:15: error: type 'FANoBiasConv2D<Scalar>' does not conform to protocol 'Layer'
// public struct FANoBiasConv2D<Scalar: TensorFlowFloatingPoint>: FALayer {
//               ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:49:10: note: candidate is missing attribute '@differentiable'
//     func callAsFunction(_ input: Input) -> Output {
//          ^
//     @differentiable
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:113:15: error: type 'FANoBiasConv2D<Scalar>' does not conform to protocol 'Module'
// public struct FANoBiasConv2D<Scalar: TensorFlowFloatingPoint>: FALayer {
//               ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:49:10: note: candidate is missing attribute '@differentiable'
//     func callAsFunction(_ input: Input) -> Output {
//          ^
//     @differentiable
// TensorFlow.Layer:3:10: note: protocol requires function 'callAsFunction' with type '(FANoBiasConv2D<Scalar>.Input) -> FANoBiasConv2D<Scalar>.Output'
//     func callAsFunction(_ input: Self.Input) -> Self.Output
//          ^
// TensorFlow.Module:5:10: note: protocol requires function 'callAsFunction' with type '(FANoBiasConv2D<Scalar>.Input) -> FANoBiasConv2D<Scalar>.Output'
//     func callAsFunction(_ input: Self.Input) -> Self.Output
//          ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:175:15: error: type 'FAConv2D<Scalar>' does not conform to protocol 'Layer'
// public struct FAConv2D<Scalar: TensorFlowFloatingPoint>: FALayer {
//               ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:49:10: note: candidate is missing attribute '@differentiable'
//     func callAsFunction(_ input: Input) -> Output {
//          ^
//     @differentiable
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:175:15: error: type 'FAConv2D<Scalar>' does not conform to protocol 'Module'
// public struct FAConv2D<Scalar: TensorFlowFloatingPoint>: FALayer {
//               ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:49:10: note: candidate is missing attribute '@differentiable'
//     func callAsFunction(_ input: Input) -> Output {
//          ^
//     @differentiable
// TensorFlow.Layer:3:10: note: protocol requires function 'callAsFunction' with type '(FAConv2D<Scalar>.Input) -> FAConv2D<Scalar>.Output'
//     func callAsFunction(_ input: Self.Input) -> Self.Output
//          ^
// TensorFlow.Module:5:10: note: protocol requires function 'callAsFunction' with type '(FAConv2D<Scalar>.Input) -> FAConv2D<Scalar>.Output'
//     func callAsFunction(_ input: Self.Input) -> Self.Output
//          ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:241:15: error: type 'FAAvgPool2D<Scalar>' does not conform to protocol 'Layer'
// public struct FAAvgPool2D<Scalar: TensorFlowFloatingPoint>: FALayer {
//               ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:49:10: note: candidate is missing attribute '@differentiable'
//     func callAsFunction(_ input: Input) -> Output {
//          ^
//     @differentiable
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:241:15: error: type 'FAAvgPool2D<Scalar>.TangentVector' does not conform to protocol 'VectorProtocol'
// public struct FAAvgPool2D<Scalar: TensorFlowFloatingPoint>: FALayer {
//               ^
// TensorFlow.Layer:3:10: note: protocol requires function 'callAsFunction' with type '(FAAvgPool2D<Scalar>.Input) -> FAAvgPool2D<Scalar>.Output'
//     func callAsFunction(_ input: Self.Input) -> Self.Output
//          ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:281:15: error: type 'FAGlobalAvgPool2D<Scalar>' does not conform to protocol 'Layer'
// public struct FAGlobalAvgPool2D<Scalar: TensorFlowFloatingPoint>: FALayer {
//               ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:49:10: note: candidate is missing attribute '@differentiable'
//     func callAsFunction(_ input: Input) -> Output {
//          ^
//     @differentiable
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:281:15: error: type 'FAGlobalAvgPool2D<Scalar>.TangentVector' does not conform to protocol 'VectorProtocol'
// public struct FAGlobalAvgPool2D<Scalar: TensorFlowFloatingPoint>: FALayer {
//               ^
// TensorFlow.Layer:3:10: note: protocol requires function 'callAsFunction' with type '(FAGlobalAvgPool2D<Scalar>.Input) -> FAGlobalAvgPool2D<Scalar>.Output'
//     func callAsFunction(_ input: Self.Input) -> Self.Output
//          ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:295:1: error: type 'Array<Element>' does not conform to protocol 'Layer'
// extension Array: Layer where Element: Layer, Element.Input == Element.Output {
// ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:301:17: note: candidate is missing attribute '@differentiable'
//     public func callAsFunction(_ input: Input) -> Output {
//                 ^
//            @differentiable
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:295:1: error: conditional conformance of type 'Array<Element>' to protocol 'Layer' does not imply conformance to inherited protocol 'Module'
// extension Array: Layer where Element: Layer, Element.Input == Element.Output {
// ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:295:1: note: did you mean to explicitly state the conformance like 'extension Array: Module where ...'?
// extension Array: Layer where Element: Layer, Element.Input == Element.Output {
// ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:295:1: error: type 'Array<Element>' does not conform to protocol 'Module'
// extension Array: Layer where Element: Layer, Element.Input == Element.Output {
// ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:301:17: note: candidate is missing attribute '@differentiable'
//     public func callAsFunction(_ input: Input) -> Output {
//                 ^
//            @differentiable
// TensorFlow.Layer:3:10: note: protocol requires function 'callAsFunction' with type '(Array<Element>.Input) -> Array<Element>.Output'
//     func callAsFunction(_ input: Self.Input) -> Self.Output
//          ^
// TensorFlow.Module:5:10: note: protocol requires function 'callAsFunction' with type '(Array<Element>.Input) -> Array<Element>.Output'
//     func callAsFunction(_ input: Self.Input) -> Self.Output
//          ^
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:340:27: error: cannot find type 'AllDifferentiableVariables' in scope
//     public var variables: AllDifferentiableVariables {
//                           ^~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:315:54: error: type of expression is ambiguous without more context
//             let (newActivation, newPullback) = layer.valueWithPullback(at: activation) { $0($1) }
//                                                ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jmd/workspace/fastai/course-v3/nbs/swift/FastaiNotebook_01a_fastai_layers/Sources/FastaiNotebook_01a_fastai_layers/01a_fastai_layers.swift:342:15: error: cannot find 'allDifferentiableVariables' in scope
//         set { allDifferentiableVariables = newValue }
//               ^~~~~~~~~~~~~~~~~~~~~~~~~~
// Install Error: swift-build returned nonzero exit code 1.

// %%
%include "EnableIPythonDisplay.swift"
import Foundation
import SwiftCV
import Path

// %%
import FastaiNotebook_08_data_block

// %%
// display opencv version
print(cvVersion())
// Out:
// error: <Cell 5>:2:7: error: cannot find 'cvVersion' in scope
// print(cvVersion())
//       ^~~~~~~~~
